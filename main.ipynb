# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
movies = pd.read_csv("movies.csv")

# %%
movies.head(2)
# Out:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  ... runtime  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  ...   162.0
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615  ...   169.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
#
#                                       title vote_average vote_count  \
# 0                                    Avatar          7.2      11800
# 1  Pirates of the Caribbean: At World's End          6.9       4500
#
#                                                 cast  \
# 0  Sam Worthington Zoe Saldana Sigourney Weaver S...
# 1  Johnny Depp Orlando Bloom Keira Knightley Stel...
#
#                                                 crew        director
# 0  [{'name': 'Stephen E. Rivkin', 'gender': 0, 'd...   James Cameron
# 1  [{'name': 'Dariusz Wolski', 'gender': 2, 'depa...  Gore Verbinski
#
# [2 rows x 24 columns]

# %%
movies.columns
# Out:
# Index(['index', 'budget', 'genres', 'homepage', 'id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director'],
#       dtype='object')

# %%
movies.shape
# Out:
# (4803, 24)

# %%
movies = movies[["id","genres","keywords","original_language","title","overview","tagline","cast","director"]]
movies.head(2)
# Out:
#       id                                    genres  \
# 0  19995  Action Adventure Fantasy Science Fiction
# 1    285                  Adventure Fantasy Action
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
#
#                                                 cast        director
# 0  Sam Worthington Zoe Saldana Sigourney Weaver S...   James Cameron
# 1  Johnny Depp Orlando Bloom Keira Knightley Stel...  Gore Verbinski

# %%
movies.shape
# Out:
# (4803, 9)

# %%
movies.columns
# Out:
# Index(['id', 'genres', 'keywords', 'original_language', 'title', 'overview',
#        'tagline', 'cast', 'director'],
#       dtype='object')

# %%
movies["tags"] = movies["keywords"] + movies["overview"] + movies["tagline"] + movies["cast"] + movies["director"]

# %%
movies["original_language"].describe()
# Out:
# count     4803
# unique      37
# top         en
# freq      4505
# Name: original_language, dtype: object

# %%
movies = movies.drop(columns=["cast","director","keywords","overview","tagline","original_language"])

# %%
movies["tags"]
# Out:
# 0       culture clash future space war space colony so...
# 1       ocean drug abuse exotic island east india trad...
# 2       spy based on novel secret agent sequel mi6A cr...
# 3       dc comics crime fighter terrorist secret ident...
# 4       based on novel mars medallion space travel pri...
#                               ...
# 4798    united states\u2013mexico barrier legs arms pa...
# 4799                                                  NaN
# 4800                                                  NaN
# 4801                                                  NaN
# 4802                                                  NaN
# Name: tags, Length: 4803, dtype: object

# %% [markdown]
# **Missing values**

# %%
movies.isnull().sum()
# Out:
# id           0
# genres      28
# title        0
# tags      1046
# dtype: int64

# %%
movies["genres"] = movies["genres"].fillna("NO genre")

# %%
movies["tags"] = movies["tags"].fillna("NO information")

# %%
movies.isnull().sum()
# Out:
# id        0
# genres    0
# title     0
# tags      0
# dtype: int64

# %% [markdown]
# **Duplicate Values**

# %%
movies.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4798    False
# 4799    False
# 4800    False
# 4801    False
# 4802    False
# Length: 4803, dtype: bool

# %%
movies
# Out:
#           id                                    genres  \
# 0      19995  Action Adventure Fantasy Science Fiction
# 1        285                  Adventure Fantasy Action
# 2     206647                    Action Adventure Crime
# 3      49026               Action Crime Drama Thriller
# 4      49529          Action Adventure Science Fiction
# ...      ...                                       ...
# 4798    9367                     Action Crime Thriller
# 4799   72766                            Comedy Romance
# 4800  231617             Comedy Drama Romance TV Movie
# 4801  126186                                  NO genre
# 4802   25975                               Documentary
#
#                                          title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                                    tags
# 0     culture clash future space war space colony so...
# 1     ocean drug abuse exotic island east india trad...
# 2     spy based on novel secret agent sequel mi6A cr...
# 3     dc comics crime fighter terrorist secret ident...
# 4     based on novel mars medallion space travel pri...
# ...                                                 ...
# 4798  united states\u2013mexico barrier legs arms pa...
# 4799                                     NO information
# 4800                                     NO information
# 4801                                     NO information
# 4802                                     NO information
#
# [4803 rows x 4 columns]

# %%
# preprocesss
movies["title"] = movies["title"].str.lower()
movies["title"]
# Out:
# 0                                         avatar
# 1       pirates of the caribbean: at world's end
# 2                                        spectre
# 3                          the dark knight rises
# 4                                    john carter
#                           ...
# 4798                                 el mariachi
# 4799                                   newlyweds
# 4800                   signed, sealed, delivered
# 4801                            shanghai calling
# 4802                           my date with drew
# Name: title, Length: 4803, dtype: object

# %%
movies.iloc[0].genres  
# Multi-label categorical data stored as text tokens
# Out:
# 'Action Adventure Fantasy Science Fiction'

# %%
movies.tags[0]
# Out:
# 'culture clash future space war space colony societyIn the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.Enter the World of Pandora.Sam Worthington Zoe Saldana Sigourney Weaver Stephen Lang Michelle RodriguezJames Cameron'

# %%
movies.id[0]
# Out:
# 19995

# %%
movies.genres[0]
# Out:
# 'Action Adventure Fantasy Science Fiction'

# %%
movies.title[0]
# Out:
# 'avatar'

# %%
movies["content"] = movies["genres"] + movies["tags"]
movies['content']
# Out:
# 0       Action Adventure Fantasy Science Fictioncultur...
# 1       Adventure Fantasy Actionocean drug abuse exoti...
# 2       Action Adventure Crimespy based on novel secre...
# 3       Action Crime Drama Thrillerdc comics crime fig...
# 4       Action Adventure Science Fictionbased on novel...
#                               ...
# 4798    Action Crime Thrillerunited states\u2013mexico...
# 4799                         Comedy RomanceNO information
# 4800          Comedy Drama Romance TV MovieNO information
# 4801                               NO genreNO information
# 4802                            DocumentaryNO information
# Name: content, Length: 4803, dtype: object

# %%
movies
# Out:
#           id                                    genres  \
# 0      19995  Action Adventure Fantasy Science Fiction
# 1        285                  Adventure Fantasy Action
# 2     206647                    Action Adventure Crime
# 3      49026               Action Crime Drama Thriller
# 4      49529          Action Adventure Science Fiction
# ...      ...                                       ...
# 4798    9367                     Action Crime Thriller
# 4799   72766                            Comedy Romance
# 4800  231617             Comedy Drama Romance TV Movie
# 4801  126186                                  NO genre
# 4802   25975                               Documentary
#
#                                          title  \
# 0                                       avatar
# 1     pirates of the caribbean: at world's end
# 2                                      spectre
# 3                        the dark knight rises
# 4                                  john carter
# ...                                        ...
# 4798                               el mariachi
# 4799                                 newlyweds
# 4800                 signed, sealed, delivered
# 4801                          shanghai calling
# 4802                         my date with drew
#
#                                                    tags  \
# 0     culture clash future space war space colony so...
# 1     ocean drug abuse exotic island east india trad...
# 2     spy based on novel secret agent sequel mi6A cr...
# 3     dc comics crime fighter terrorist secret ident...
# 4     based on novel mars medallion space travel pri...
# ...                                                 ...
# 4798  united states\u2013mexico barrier legs arms pa...
# 4799                                     NO information
# 4800                                     NO information
# 4801                                     NO information
# 4802                                     NO information
#
#                                                 content
# 0     Action Adventure Fantasy Science Fictioncultur...
# 1     Adventure Fantasy Actionocean drug abuse exoti...
# 2     Action Adventure Crimespy based on novel secre...
# 3     Action Crime Drama Thrillerdc comics crime fig...
# 4     Action Adventure Science Fictionbased on novel...
# ...                                                 ...
# 4798  Action Crime Thrillerunited states\u2013mexico...
# 4799                       Comedy RomanceNO information
# 4800        Comedy Drama Romance TV MovieNO information
# 4801                             NO genreNO information
# 4802                          DocumentaryNO information
#
# [4803 rows x 5 columns]

# %%
tfidf = TfidfVectorizer(stop_words="english")
tfidf
# Out:
# TfidfVectorizer(stop_words='english')

# %%
tfidf_matrix = tfidf.fit_transform(movies["content"])
tfidf_matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 178615 stored elements and shape (4803, 34748)>

# %%
similarity = cosine_similarity(tfidf_matrix)
similarity
# Out:
# array([[1.        , 0.02384228, 0.00791086, ..., 0.        , 0.        ,
#         0.        ],
#        [0.02384228, 1.        , 0.00938354, ..., 0.        , 0.        ,
#         0.        ],
#        [0.00791086, 0.00938354, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.08415495,
#         0.09132274],
#        [0.        , 0.        , 0.        , ..., 0.08415495, 1.        ,
#         0.1566181 ],
#        [0.        , 0.        , 0.        , ..., 0.09132274, 0.1566181 ,
#         1.        ]])

# %%
movies
# Out:
#           id                                    genres  \
# 0      19995  Action Adventure Fantasy Science Fiction
# 1        285                  Adventure Fantasy Action
# 2     206647                    Action Adventure Crime
# 3      49026               Action Crime Drama Thriller
# 4      49529          Action Adventure Science Fiction
# ...      ...                                       ...
# 4798    9367                     Action Crime Thriller
# 4799   72766                            Comedy Romance
# 4800  231617             Comedy Drama Romance TV Movie
# 4801  126186                                  NO genre
# 4802   25975                               Documentary
#
#                                          title  \
# 0                                       avatar
# 1     pirates of the caribbean: at world's end
# 2                                      spectre
# 3                        the dark knight rises
# 4                                  john carter
# ...                                        ...
# 4798                               el mariachi
# 4799                                 newlyweds
# 4800                 signed, sealed, delivered
# 4801                          shanghai calling
# 4802                         my date with drew
#
#                                                    tags  \
# 0     culture clash future space war space colony so...
# 1     ocean drug abuse exotic island east india trad...
# 2     spy based on novel secret agent sequel mi6A cr...
# 3     dc comics crime fighter terrorist secret ident...
# 4     based on novel mars medallion space travel pri...
# ...                                                 ...
# 4798  united states\u2013mexico barrier legs arms pa...
# 4799                                     NO information
# 4800                                     NO information
# 4801                                     NO information
# 4802                                     NO information
#
#                                                 content
# 0     Action Adventure Fantasy Science Fictioncultur...
# 1     Adventure Fantasy Actionocean drug abuse exoti...
# 2     Action Adventure Crimespy based on novel secre...
# 3     Action Crime Drama Thrillerdc comics crime fig...
# 4     Action Adventure Science Fictionbased on novel...
# ...                                                 ...
# 4798  Action Crime Thrillerunited states\u2013mexico...
# 4799                       Comedy RomanceNO information
# 4800        Comedy Drama Romance TV MovieNO information
# 4801                             NO genreNO information
# 4802                          DocumentaryNO information
#
# [4803 rows x 5 columns]

# %% [markdown]
# **Recommendor function**

# %%
"""
def recommend(movie_title, df, similarity_matrix, top_n=5):
    """"""
    movie_title: user input
    df: your movies dataframe with 'title' and 'id'
    similarity_matrix: precomputed similarity (cosine) between movies
    top_n: number of recommendations
    """""""
    
    # 1. Normalize user input
    movie_title = movie_title.lower()
    
    # 2. Find the movie index
    movie_row = df[df['title'].str.lower() == movie_title]
    
    if movie_row.empty:
        return "Movie not found"
    
    movie_index = movie_row.index[0]  # get the row index
    
    # 3. Get similarity scores for this movie with all others
    sim_scores = list(enumerate(similarity_matrix[movie_index]))
    
    # 4. Sort movies by similarity (highest first)
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # 5. Pick top_n movies (skip the first one, it's the same movie)
    top_movies = sim_scores[1:top_n+1]
    
    # 6. Get movie titles for these indices
    recommended_titles = [df.iloc[i[0]]['title'] for i in top_movies]
    
    return recommended_titles
"""
# Out:
# '\ndef recommend(movie_title, df, similarity_matrix, top_n=5):\n    \n    movie_title: user input\n    df: your movies dataframe with \'title\' and \'id\'\n    similarity_matrix: precomputed similarity (cosine) between movies\n    top_n: number of recommendations\n    "\n\n    # 1. Normalize user input\n    movie_title = movie_title.lower()\n\n    # 2. Find the movie index\n    movie_row = df[df[\'title\'].str.lower() == movie_title]\n\n    if movie_row.empty:\n        return "Movie not found"\n\n    movie_index = movie_row.index[0]  # get the row index\n\n    # 3. Get similarity scores for this movie with all others\n    sim_scores = list(enumerate(similarity_matrix[movie_index]))\n\n    # 4. Sort movies by similarity (highest first)\n    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)\n\n    # 5. Pick top_n movies (skip the first one, it\'s the same movie)\n    top_movies = sim_scores[1:top_n+1]\n\n    # 6. Get movie titles for these indices\n    recommended_titles = [df.iloc[i[0]][\'title\'] for i in top_movies]\n\n    return recommended_titles\n'

# %%
# recommend("Titanic", movies, similarity, top_n=2)

# %%
def recommendor(user_input,df,similarity_matrix,top_n):
    #load the data
    movie_title = df["title"].values

    #search for movie index
    movie_row= df[df["title"].str.lower() == user_input.lower()]

    #if moviename is not found
    if user_input not in movie_title:
        print("Movie not found")
        return

    #get the row index
    movie_index = movie_row.index[0]

    #get similarity score
    sim_score = []

    row = similarity_matrix[movie_index]

    for i in range(len(row)):
        sim_score.append((i,row[i]))

    print(sim_score)

    #Sort Movies by Similarity (Selection Sort )
    for i in range(len(sim_score)):
        min_idx = i
        for j in range(i+1,len(sim_score)):
            if sim_score[j][1] > sim_score[min_idx][1]:
                min_idx = j
        sim_score[i], sim_score[min_idx] = sim_score[min_idx], sim_score[i]
    print(sim_score)

    #pick the top n movies
    top_movies = sim_score[1:top_n+1]

    #Recommended Titles
    recommended_titles = []

    for movie in top_movies:
        rec_index = movie[0]
        title = df.iloc[movie_index]['title']  # get title
        recommended_titles.append(title)

    return recommended_titles

# %%
recommendor("avatar",movies,similarity,top_n=6)
# Out:
# [(0, 1.0), (1, 0.02384228483305085), (2, 0.007910864111627088), (3, 0.002632121538888598), (4, 0.05361155038452979), (5, 0.023413110221807927), (6, 0.005694689344555998), (7, 0.03821320097607796), (8, 0.01328067148210536), (9, 0.01823472140711619), (10, 0.10416982287693935), (11, 0.016453004825764197), (12, 0.013758015922827261), (13, 0.006059972783721852), (14, 0.03566042830009508), (15, 0.0034774427078752466), (16, 0.013516599042579203), (17, 0.011242395808032187), (18, 0.02750146965403312), (19, 0.005265506839875211), (20, 0.005709326840516008), (21, 0.003151746727046717), (22, 0.004448566684513243), (23, 0.020961117869033513), (24, 0.00976053471799084), (25, 0.009651290748721687), (26, 0.03334534483551238), (27, 0.05784607742601942), (28, 0.017049236099064006), (29, 0.025788952952348627), (30, 0.007353970716277285), (31, 0.05252101722394274), (32, 0.015212608861899249), (33, 0.014650314942500336), (34, 0.0), (35, 0.018685303771642812), (36, 0.059017018083370364), (37, 0.026590385776090984), (38, 0.006401421128472515), (39, 0.029929236243754806), (40, 0.013342906815311188), (41, 0.035447991701282364), (42, 0.0), (43, 0.09555797668095029), (44, 0.018023515983913663), (45, 0.04376868700882584), (46, 0.05596492435812439), (47, 0.0853573023530244), (48, 0.014046008595604353), (49, 0.004302568033594558), (50, 0.02023216508652432), (51, 0.00967476002135219), (52, 0.04750872372454154), (53, 0.01803409480083532), (54, 0.011161695637939367), (55, 0.002751690928532116), (56, 0.07306934119453329), (57, 0.029468580844010123), (58, 0.00631264133099188), (59, 0.024048191023412147), (60, 0.010119454050946285), (61, 0.04470467456968063), (62, 0.0037830920339430125), (63, 0.007759930138304661), (64, 0.018626341295153875), (65, 0.009882169148004345), (66, 0.0), (67, 0.03588137815133775), (68, 0.0326163641093775), (69, 0.008772439741219079), (70, 0.01943209026924464), (71, 0.0432222651236659), (72, 0.02986642997218833), (73, 0.008925953747817092), (74, 0.03303834990972756), (75, 0.008105090803083212), (76